# %% [markdown]
# # 2D Greeks Graphs

# %% [markdown]
# ### Import visualizer and create an Option object

# %%
import visualizer as vis
opt = vis.Option()

# %% [markdown]
# ### The greeks function can be used to show graphs of 2D or 3D graphs (defaulting to 2D). The default arguments displays Long 3M Call Delta vs Time with Strikes at 90%, ATM and 110%

# %%
opt.greeks(graphtype='2D')

# %% [markdown]
# ### The x and y axis arguments are referenced using x_plot and y_plot, here Delta vs Price

# %%
opt.greeks(x_plot='price', y_plot='delta', G1=100, G2=100, G3=100, T1=0.05, T2=0.15, T3=0.25)

# %% [markdown]
# ### Strikes are referenced as G1, G2 & G3 and Direction as long or short, here Delta vs Volatility

# %%
opt.greeks(x_plot='vol', y_plot='delta', G1=80, G2=90, G3=100, direction='short')

# %% [markdown]
# ### Option can be specified as call or put, here Delta vs Time

# %%
opt.greeks(x_plot='time', y_plot='delta', option='put', G1=105, G2=110, G3=115, direction='short')

# %% [markdown]
# ### Value vs Price

# %%
opt.greeks(x_plot='price', y_plot='value')

# %%
opt.greeks(x_plot='vol', y_plot='value')

# %%
opt.greeks(x_plot='time', y_plot='value', option='put')

# %%
opt.greeks(x_plot='price', y_plot='gamma', direction='short')

# %%
opt.greeks(x_plot='vol', y_plot='gamma')

# %%
opt.greeks(x_plot='time', y_plot='gamma')

# %%
opt.greeks(x_plot='price', y_plot='vega', G1=100, G2=100, G3=100, T1=0.05, T2=0.15, T3=0.25)

# %%
opt.greeks(x_plot='vol', y_plot='vega', direction='short')

# %%
opt.greeks(x_plot='time', y_plot='vega')

# %%
opt.greeks(x_plot='price', y_plot='theta', G1=100, G2=100, G3=100, T1=0.05, T2=0.15, T3=0.25)

# %%
opt.greeks(x_plot='vol', y_plot='theta')

# %%
opt.greeks(x_plot='time', y_plot='theta', direction='short', option='put')

# %%
opt.greeks(x_plot='price', y_plot='rho', time_shift=0.5)

# %%
opt.greeks(x_plot='strike', y_plot='rho', direction='short')

# %%
opt.greeks(x_plot='vol', y_plot='rho', r=0.005)
