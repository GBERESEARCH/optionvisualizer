# %% [markdown]
# # Option Payoff Graphs

# %% [markdown]
# ### Import pricer and create an Option object

# %%
import pricer as opv
opt = opv.Option()

# %% [markdown]
# ### Payoffs can be referenced directly by name and come with default parameters so can be run without arguments

# %%
opt.call()

# %% [markdown]
# ### Or you can be explicit about any or all arguments

# %%
opt.call(S0=90, K=95, T=0.75, r=0.05, q=0, sigma=0.3, direction='short', value=True)

# %%
opt.put()

# %%
opt.stock()

# %%
opt.forward()

# %% [markdown]
# ### Alternatively each payoff can be accessed from the payoff_graphs function via the combo payoff argument

# %%
opt.payoff_graphs(combo_payoff='collar')

# %%
opt.payoff_graphs(combo_payoff='spread', direction='long', option='put')

# %%
opt.payoff_graphs(combo_payoff='backspread', ratio=3, value=True)

# %%
opt.payoff_graphs(combo_payoff='ratio vertical spread', ratio=3, option='put')

# %%
opt.payoff_graphs(combo_payoff='straddle')

# %%
opt.payoff_graphs(combo_payoff='strangle', S0=50, K1=45, K2=55, direction='short')

# %%
opt.payoff_graphs(combo_payoff='butterfly', value=True)

# %%
opt.payoff_graphs(combo_payoff='christmas tree', value=True, direction='short')

# %%
opt.payoff_graphs(combo_payoff='iron butterfly')

# %%
opt.payoff_graphs(combo_payoff='iron condor', value=True)
